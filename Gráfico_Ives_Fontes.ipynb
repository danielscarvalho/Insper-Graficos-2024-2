# %%
import matplotlib.pyplot as plt

# Dados do gráfico
x = [1, 2, 3, 4, 5]
y = [10, 12, 14, 16, 18]

# Criar o gráfico
plt.plot(x, y)
plt.title('Gráfico de Exemplo')
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')

# Mostrar o gráfico
plt.show()
